# %% [markdown]
# # Seaborn Basics

# %%
import pandas as pd
import seaborn as sns

# %%
data = sns.load_dataset("tips")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **In this data tip is the depenedent feature and remaining are independent features. Here we are trying to learn seaborn using its EDA.**

# %% [markdown]
# ## 1. Heatmap
# ##### Correlation with Heatmap
# correlation helps to find out the inter relation between all the features(features with integer and float value only. categorical values are not applicable for correlation)

# %%
data_with_dummies = pd.get_dummies(data, drop_first = True)

# %% [raw]
# data_with_dummies.corr()

# %%
selected_col = ['total_bill', 'tip', 'size']
new_data = data[selected_col]
new_data
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
sns.heatmap(new_data.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## 2. JoinPlot
# jointplot is a function used to create a multi-panel figure that displays both a univariate distribution of each variable along the diagonal axes and a bivariate visualization of the relationship between two variables in the off-diagonal panels.
#
# **Univariate Distributions:**
#
# Along the diagonal of the plot, separate univariate histograms or kernel density estimates are plotted for each variable. These histograms or kernel density estimates show the distribution of each variable individuall
#
# **Bivariate Relationship:**
#
# In the off-diagonal panels, a bivariate scatter plot or hexbin plot is displayed to show the relationship between the two variables. This allows you to visualize how the variables interact with each other.y.

# %%
sns.jointplot(x="tip", y="total_bill", data = data, kind = "hex")

# %%
# here type is regression
sns.jointplot(x="tip", y="total_bill", data = data, kind = "hex")

# %% [markdown]
# ### 3. Pair Plot or Scatter plot
# if the number of features are more than 2 we use pair plot or scatter plot

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue = "sex")

# %% [markdown]
# ### 4. Dist Plot
# **It has been replaced by histplot() and displot()**

# %%
sns.histplot(data["tip"], kde = True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### Categorical Plots

# %% [markdown]
# #### 1. Count plot

# %%
sns.countplot(data = data, x = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# #### 2. Barplot
#
# In barplot both x value and y value are specified

# %%
sns.barplot(x = 'total_bill', y = 'sex', data = data)
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %% [markdown]
# #### 3. Boxplot

# %%
sns.boxplot(x = 'sex', y = 'total_bill', data = data)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# #### 4. Violinplot
# Violinplot helps us to see both the distribution of the data and boxplot

# %%
sns.violinplot( y = 'total_bill', data = data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
